# %% [markdown]
# <a href="https://colab.research.google.com/github/joshuajhchoi/ai2learn/blob/master/Smiling_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab에서 파일 업로드
from google.colab import files

# 업로드된 이미지 파일 경로
uploaded = files.upload()
image_path = list(uploaded.keys())[0]  # 업로드된 첫 번째 파일 경로

# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 # Download the pre-trained model
# !bzip2 -d shape_predictor_68_face_landmarks.dat.bz2 # Unzip the model

import dlib
import cv2
import numpy as np
import tensorflow_hub as hub

# Load pre-trained face detector
detector = dlib.get_frontal_face_detector()

# Load pre-trained face landmark detector
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# Load pre-trained facial expression recognition model from TF Hub
# The original model was not found, using a different model instead
model = hub.load("https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/classification/5")

# 이미지 불러오기
image = cv2.imread(image_path)

# Detect faces in the image
faces = detector(image)

for face in faces:
  # Get the face landmarks
  landmarks = predictor(image, face)
  landmarks_np = np.array([[p.x, p.y] for p in landmarks.parts()])

  # Crop the face region
  x, y, w, h = face.left(), face.top(), face.right() - face.left(), face.bottom() - face.top()
  face_image = image[y:y+h, x:x+w]

  # Preprocess the face image for the model
  face_image = cv2.resize(face_image, (224, 224))
  face_image = face_image / 255.0
  face_image = np.expand_dims(face_image, axis=0)

  # Predict the facial expression
  predicted_expression = model(face_image)[0]
  predicted_expression_index = predicted_expression.numpy().argmax()

  # Map the predicted expression to a funny caption
  # This section needs to be updated as the model is different and
  # does not return emotions.
  expressions = ["happy", "sad", "angry", "surprise", "fear", "disgust"]
  predicted_expression = expressions[predicted_expression_index]

  if predicted_expression == "happy":
    caption = " 웃는 얼굴이 아주 밝네요!"
  elif predicted_expression == "sad":
    # ... (다른 표정에 대한 캡션 추가)
  # ... (다른 표정에 대한 캡션 추가)

  # Draw the caption on the image
    cv2.putText(image, caption, (face.left(), face.top()), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

cv2.imshow("Image with Captions", image)
cv2.waitKey(0)
# Out:
#      <input type="file" id="files-1a83185f-5658-49b3-97ca-ef94142e15b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a83185f-5658-49b3-97ca-ef94142e15b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
